# %% [markdown]
# # The ER2 MVP
#
# The program of ARCHITECTURE.md §5, run by the `er2` kernel. In a standard `python3` kernel, run `%load_ext er2` first.

# %% [markdown]
# ## Computer algebra (SymPy)

# %%
sym x
f = x^2 + 2*x + 1
print(f)
print(expand(f))
print(factor(f))

# %%
show(factor(f))

# %%
print(latex(f))

# %% [markdown]
# ## Number theory (PARI)

# %%
print(factor(2^127 - 1))
print(phi(123456789))
print(sigma(123456789))
print(isprime(2^521 - 1))

# %%
for k in range(1, 20):
    if isprime(k):
        print(k)
